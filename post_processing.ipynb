# %%
import numpy as np
import matplotlib.pyplot as plt
import csv 

data_13 = np.genfromtxt('processed_data_N=13.csv', delimiter=",",skip_header=1)
data_25 = np.genfromtxt('processed_data_N=25.csv', delimiter=",",skip_header=1)
N=13
theta = np.linspace(0,np.pi/2,N)
rounds = [1,2,3,4,5,6,7,8,9]

# AT
dat_AT_clean = [[],[],[],[],[],[],[],[],[]]
fid_AT_clean = [[],[],[],[],[],[],[],[],[]]
diff_AT_clean = [[],[],[],[],[],[],[],[],[]]
dat_AT_noisy = [[],[],[],[],[],[],[],[],[]]
fid_AT_noisy = [[],[],[],[],[],[],[],[],[]]
diff_AT_noisy = [[],[],[],[],[],[],[],[],[]]
# SCM
dat_SCM_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCM_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCM_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCM_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCM_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCM_noisy = [[],[],[],[],[],[],[],[],[]]
#############################
# SCMWEP full, alpha=0
dat_SCMWEP_full_0_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_0_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_0_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_full_0_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_0_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_0_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP full, alpha=pi/4
dat_SCMWEP_full_1_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_1_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_1_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_full_1_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_1_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_1_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP full, alpha=pi/2
dat_SCMWEP_full_2_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_2_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_2_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_full_2_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_2_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_2_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP full, alpha=3pi/4
dat_SCMWEP_full_3_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_3_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_3_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_full_3_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_3_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_3_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP full, alpha=pi
dat_SCMWEP_full_4_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_4_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_4_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_full_4_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_full_4_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_full_4_noisy = [[],[],[],[],[],[],[],[],[]]
#############################
# SCMWEP lim 1, alpha=0
dat_SCMWEP_lim_0_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_0_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_0_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim_0_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_0_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_0_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi/4
dat_SCMWEP_lim_1_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_1_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_1_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim_1_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_1_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_1_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi/2
dat_SCMWEP_lim_2_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_2_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_2_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim_2_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_2_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_2_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=3pi/4
dat_SCMWEP_lim_3_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_3_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_3_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim_3_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_3_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_3_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi
dat_SCMWEP_lim_4_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_4_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_4_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim_4_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim_4_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim_4_noisy = [[],[],[],[],[],[],[],[],[]]
#############################
# SCMWEP lim 2, alpha=0
dat_SCMWEP_lim2_0_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_0_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_0_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_0_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_0_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_0_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi/4
dat_SCMWEP_lim2_1_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_1_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_1_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_1_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_1_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_1_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi/2
dat_SCMWEP_lim2_2_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_2_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_2_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_2_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_2_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_2_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=3pi/4
dat_SCMWEP_lim2_3_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_3_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_3_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_3_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_3_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_3_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=pi
dat_SCMWEP_lim2_4_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_4_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_4_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_4_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_4_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_4_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=1.5pi
dat_SCMWEP_lim2_5_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_5_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_5_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_5_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_5_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_5_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=2pi
dat_SCMWEP_lim2_6_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_6_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_6_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_6_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_6_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_6_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=2.5pi
dat_SCMWEP_lim2_7_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_7_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_7_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_7_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_7_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_7_noisy = [[],[],[],[],[],[],[],[],[]]
# SCMWEP lim 2, alpha=3pi
dat_SCMWEP_lim2_8_clean = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_8_clean = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_8_clean = [[],[],[],[],[],[],[],[],[]]
dat_SCMWEP_lim2_8_noisy = [[],[],[],[],[],[],[],[],[]]
fid_SCMWEP_lim2_8_noisy = [[],[],[],[],[],[],[],[],[]]
diff_SCMWEP_lim2_8_noisy = [[],[],[],[],[],[],[],[],[]]

'''
theta = 1
alpha = 2
prob = 3
rounds = 4
type = 5
dat_clean = 6
fid_clean = 7
diff_clean = 8
dat_noisy = 12
fid_noisy = 13
diff_noisy = 14
'''

for i in range(len(data_13)):
    for j in rounds:
        ## AT
        if data_13[i][5]==1 and data_13[i][4]==j: 
            dat_AT_clean[j-1].append(data_13[i][6])
            fid_AT_clean[j-1].append(data_13[i][7])
            diff_AT_clean[j-1].append(data_13[i][8])
            dat_AT_noisy[j-1].append(data_13[i][12])
            fid_AT_noisy[j-1].append(data_13[i][13])
            diff_AT_noisy[j-1].append(data_13[i][14])
        ## SCM
        elif data_13[i][5]==2and data_13[i][4]==j:
            dat_SCM_clean[j-1].append(data_13[i][6])
            fid_SCM_clean[j-1].append(data_13[i][7])
            diff_SCM_clean[j-1].append(data_13[i][8])
            dat_SCM_noisy[j-1].append(data_13[i][12])
            fid_SCM_noisy[j-1].append(data_13[i][13])
            diff_SCM_noisy[j-1].append(data_13[i][14])
        ###################################################################################
        ## SCMWEP full, alpha=0
        elif data_13[i][5]==3 and data_13[i][4]==j and data_13[i][2]==0:
            dat_SCMWEP_full_0_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_full_0_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_full_0_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_full_0_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_full_0_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_full_0_noisy[j-1].append(data_13[i][14])
        ## SCMWEP full, alpha=pi/4
        elif data_13[i][5]==3 and data_13[i][4]==j and np.pi/4+0.1>data_13[i][2]>np.pi/4-0.1:
            dat_SCMWEP_full_1_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_full_1_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_full_1_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_full_1_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_full_1_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_full_1_noisy[j-1].append(data_13[i][14])
        ## SCMWEP full, alpha=pi/2
        elif data_13[i][5]==3 and data_13[i][4]==j and np.pi/2+0.1>data_13[i][2]>np.pi/2-0.1:
            dat_SCMWEP_full_2_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_full_2_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_full_2_noisy[j-1].append(data_13[i][8])
            dat_SCMWEP_full_2_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_full_2_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_full_2_noisy[j-1].append(data_13[i][14])
        ## SCMWEP full, alpha=3pi/4
        elif data_13[i][5]==3 and data_13[i][4]==j and 3*np.pi/4+0.1>data_13[i][2]>3*np.pi/4-0.1:
            dat_SCMWEP_full_3_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_full_3_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_full_3_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_full_3_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_full_3_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_full_3_noisy[j-1].append(data_13[i][14])
        ## SCMWEP full, alpha=pi
        elif data_13[i][5]==3 and data_13[i][4]==j and np.pi+0.1>data_13[i][2]>np.pi-0.1:
            dat_SCMWEP_full_4_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_full_4_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_full_4_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_full_4_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_full_4_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_full_4_noisy[j-1].append(data_13[i][14])
        ###################################################################################
        ## SCMWEP lim1, alpha=0
        elif data_13[i][5]==4 and data_13[i][4]==j and data_13[i][2]==0:
            dat_SCMWEP_lim_0_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim_0_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim_0_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim_0_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim_0_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim_0_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim1, alpha=pi/4
        elif data_13[i][5]==4 and data_13[i][4]==j and np.pi/4+0.1>data_13[i][2]>np.pi/4-0.1:
            dat_SCMWEP_lim_1_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim_1_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim_1_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim_1_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim_1_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim_1_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim1, alpha=pi/2
        elif data_13[i][5]==4 and data_13[i][4]==j and np.pi/2+0.1>data_13[i][2]>np.pi/2-0.1:
            dat_SCMWEP_lim_2_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim_2_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim_2_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim_2_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim_2_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim_2_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim1, alpha=3pi/4
        elif data_13[i][5]==4 and data_13[i][4]==j and 3*np.pi/4+0.1>data_13[i][2]>3*np.pi/4-0.1:
            dat_SCMWEP_lim_3_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim_3_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim_3_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim_3_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim_3_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim_3_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim1, alpha=pi
        elif data_13[i][5]==4 and data_13[i][4]==j and np.pi+0.1>data_13[i][2]>np.pi-0.1:
            dat_SCMWEP_lim_4_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim_4_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim_4_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim_4_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim_4_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim_4_noisy[j-1].append(data_13[i][14])
        ###################################################################################
        ## SCMWEP lim2, alpha=0
        elif data_13[i][5]==5 and data_13[i][4]==j and data_13[i][2]==0:
            dat_SCMWEP_lim2_0_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_0_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_0_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_0_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_0_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_0_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=pi/4
        elif data_13[i][5]==5 and data_13[i][4]==j and np.pi/4+0.1>data_13[i][2]>np.pi/4-0.1:
            dat_SCMWEP_lim2_1_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_1_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_1_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_1_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_1_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_1_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=pi/2
        elif data_13[i][5]==5 and data_13[i][4]==j and np.pi/2+0.1>data_13[i][2]>np.pi/2-0.1:
            dat_SCMWEP_lim2_2_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_2_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_2_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_2_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_2_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_2_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=3pi/4
        elif data_13[i][5]==5 and data_13[i][4]==j and 3*np.pi/4+0.1>data_13[i][2]>3*np.pi/4-0.1:
            dat_SCMWEP_lim2_3_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_3_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_3_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_3_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_3_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_3_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=pi
        elif data_13[i][5]==5 and data_13[i][4]==j and np.pi+0.1>data_13[i][2]>np.pi-0.1:
            dat_SCMWEP_lim2_4_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_4_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_4_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_4_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_4_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_4_noisy[j-1].append(data_13[i][14])
        ###################################################################################
        ## SCMWEP lim2, alpha=1.5pi
        elif data_13[i][5]==6 and data_13[i][4]==j and 1.5*np.pi+0.1>data_13[i][2]>1.5*np.pi-0.1:
            dat_SCMWEP_lim2_5_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_5_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_5_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_5_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_5_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_5_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=2pi
        elif data_13[i][5]==6 and data_13[i][4]==j and 2*np.pi+0.1>data_13[i][2]>2*np.pi-0.1:
            dat_SCMWEP_lim2_6_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_6_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_6_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_6_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_6_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_6_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=2.5pi
        elif data_13[i][5]==6 and data_13[i][4]==j and 2.5*np.pi+0.1>data_13[i][2]>2.5*np.pi-0.1:
            dat_SCMWEP_lim2_7_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_7_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_7_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_7_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_7_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_7_noisy[j-1].append(data_13[i][14])
        ## SCMWEP lim2, alpha=3pi
        elif data_13[i][5]==6 and data_13[i][4]==j and 3*np.pi+0.1>data_13[i][2]>3*np.pi-0.1:
            dat_SCMWEP_lim2_8_clean[j-1].append(data_13[i][6])
            fid_SCMWEP_lim2_8_clean[j-1].append(data_13[i][7])
            diff_SCMWEP_lim2_8_clean[j-1].append(data_13[i][8])
            dat_SCMWEP_lim2_8_noisy[j-1].append(data_13[i][12])
            fid_SCMWEP_lim2_8_noisy[j-1].append(data_13[i][13])
            diff_SCMWEP_lim2_8_noisy[j-1].append(data_13[i][14])
        ##################################################################################

# %%
## AT clean 1,2,3
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_AT_clean[0],'ko',label='1 round')
plt.plot(theta,dat_AT_clean[1],'ro',label='2 rounds')
plt.plot(theta,dat_AT_clean[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='AT, noiseless')
plt.savefig('DATA_AT_123_clean.png', dpi=1000, bbox_inches='tight')

## AT clean 4,5,6
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_AT_clean[3],'ko',label='4 rounds')
plt.plot(theta,dat_AT_clean[4],'ro',label='5 rounds')
plt.plot(theta,dat_AT_clean[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='AT, noiseless')
plt.savefig('DATA_AT_456_clean.png', dpi=1000, bbox_inches='tight')

# %%
## AT noisy 1,2,3
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_AT_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_AT_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_AT_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='AT, noisy')
plt.savefig('DATA_AT_123_noisy.png', dpi=1000, bbox_inches='tight')

## AT noisy 4,5,6
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_AT_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_AT_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_AT_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='AT, noisy')
plt.savefig('DATA_AT_456_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCM clean 1,2,3
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCM_clean[0],'ko',label='1 round')
plt.plot(theta,dat_SCM_clean[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCM_clean[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCM, noiseless')
plt.savefig('DATA_SCM_123_clean.png', dpi=1000, bbox_inches='tight')

## SCM clean 4,5,6
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCM_clean[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCM_clean[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCM_clean[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCM, noiseless')
plt.savefig('DATA_SCM_456_clean.png', dpi=1000, bbox_inches='tight')

# %%
## SCM noisy 1,2,3
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCM_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCM_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCM_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCM, noisy')
plt.savefig('DATA_SCM_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCM noisy 4,5,6
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCM_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCM_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCM_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCM, noisy')
plt.savefig('DATA_SCM_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCM noisy 7,8,9
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCM_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCM_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCM_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCM, noisy')
plt.savefig('DATA_SCM_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full noisy 1,2,3, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_0_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_full_0_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_full_0_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_0_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 4,5,6, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_0_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_full_0_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_full_0_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_0_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 7,8,9, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_0_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_full_0_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_full_0_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_0_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full noisy 1,2,3, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_1_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_full_1_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_full_1_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_1_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 4,5,6, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_1_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_full_1_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_full_1_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_1_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 7,8,9, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_1_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_full_1_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_full_1_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_1_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full noisy 1,2,3, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_2_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_full_2_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_full_2_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_2_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 4,5,6, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_2_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_full_2_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_full_2_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_2_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 7,8,9, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_2_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_full_2_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_full_2_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_2_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full noisy 1,2,3, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_3_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_full_3_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_full_3_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_3_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 4,5,6, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_3_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_full_3_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_full_3_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_3_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 7,8,9, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_3_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_full_3_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_full_3_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_3_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full noisy 1,2,3, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_4_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_full_4_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_full_4_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_4_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 4,5,6, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_4_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_full_4_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_full_4_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_4_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full noisy 7,8,9, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_full_4_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_full_4_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_full_4_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_4_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_1 noisy 1,2,3, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_0_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim_0_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 4,5,6, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_0_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim_0_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 7,8,9, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_0_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim_0_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim_0_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_1 noisy 1,2,3, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_1_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_1_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 4,5,6, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_1_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_1_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 7,8,9, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_1_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim_1_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_1_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_1 noisy 1,2,3, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_2_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim_2_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 4,5,6, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_2_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim_2_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 7,8,9, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_2_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim_2_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim_2_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_1 noisy 1,2,3, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_3_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_3_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 4,5,6, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_3_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_3_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 7,8,9, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_3_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim_3_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim_3_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_1 noisy 1,2,3, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_4_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim_4_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 4,5,6, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_4_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim_4_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_1 noisy 7,8,9, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim_4_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim_4_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 1, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim_4_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_0_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim2_0_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_0_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim2_0_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=0
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_0_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_0_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=0$, noisy')
plt.savefig('DATA_SCMWEP_lim2_0_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_1_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_1_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_1_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_1_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_1_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_1_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_1_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_2_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim2_2_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_2_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim2_2_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=pi/2
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_2_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_2_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi/2$, noisy')
plt.savefig('DATA_SCMWEP_lim2_2_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_3_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_3_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_3_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_3_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=3pi/4
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_3_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_3_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi/4$, noisy')
plt.savefig('DATA_SCMWEP_lim2_3_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_4_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_4_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_4_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_4_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_4_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_4_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_4_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=1.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_5_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=1.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_5_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=1.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_5_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=1.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_5_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=1.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_5_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_5_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=1.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_5_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=2pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_6_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_6_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=2pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_6_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_6_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=2pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_6_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_6_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_6_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=2.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_7_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_7_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=2.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_7_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_7_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=2.5pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_7_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_7_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=2.5\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_7_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim_2 noisy 1,2,3, alpha=3pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_8_noisy[0],'ko',label='1 round')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[1],'ro',label='2 rounds')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[2],'bo',label='3 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_8_123_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 4,5,6, alpha=3pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_8_noisy[3],'ko',label='4 rounds')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[4],'ro',label='5 rounds')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[5],'bo',label='6 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_8_456_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim_2 noisy 7,8,9, alpha=3pi
plt.figure()
x = np.linspace(0,np.pi/2,50)
plt.plot(x,[np.arctan(np.tan(i)**2) for i in x],label = '$\\arctan(\\tan^2(\\theta))$',color = 'k')
plt.ylabel('$\\arctan(\\langle x \\rangle / \\langle z \\rangle)$',labelpad=0)
plt.xlabel('$\\theta \ (radians)$',labelpad=0)
xpositions = (0,np.pi/8,np.pi/4, 3*np.pi/8,np.pi/2)
labels = ("$0$", "$\\frac{\\pi}{8}$", "$\\frac{\\pi}{4}$","$\\frac{3\\pi}{8}$","$\\frac{\\pi}{2}$")
plt.xticks(xpositions, labels,fontsize = 12)
ypositions=(0,0.4,0.8,1.2,1.6)
plt.yticks(ypositions,fontsize=12)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.ylim(-0.1,1.7)
plt.grid()

plt.plot(theta,dat_SCMWEP_lim2_8_noisy[6],'ko',label='7 rounds')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[7],'ro',label='8 rounds')
plt.plot(theta,dat_SCMWEP_lim2_8_noisy[8],'bo',label='9 rounds')
plt.legend(loc='upper left', title='SCMWEP lim 2, $\\alpha=3\\pi$, noisy')
plt.savefig('DATA_SCMWEP_lim2_8_789_noisy.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[fid_AT_clean[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_AT_clean[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_AT_clean[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_AT_clean[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.65,1.05)
ylocations = (0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='lower right', title='Reference')
plt.savefig('FID_Reference.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[fid_AT_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_AT_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_AT_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_AT_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='AT, Noisy')
plt.savefig('FID_AT_noisy.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[fid_SCM_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCM_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCM_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCM_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCM, Noisy')
plt.savefig('FID_SCM_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full alpha=0
plt.figure()
plt.plot(rounds,[fid_SCMWEP_full_0_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_full_0_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_full_0_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_full_0_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=0$ Noisy')
plt.savefig('FID_SCMWEP_0_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_full_1_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_full_1_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_full_1_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_full_1_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_1_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi/2
plt.figure()
plt.plot(rounds,[fid_SCMWEP_full_2_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_full_2_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_full_2_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_full_2_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi/2$ Noisy')
plt.savefig('FID_SCMWEP_2_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=3pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_full_3_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_full_3_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_full_3_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_full_3_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=3\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_3_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_full_4_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_full_4_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_full_4_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_full_4_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi$ Noisy')
plt.savefig('FID_SCMWEP_4_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim 1 alpha=0
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim_0_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim_0_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim_0_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim_0_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 1, $\\alpha=0$ Noisy')
plt.savefig('FID_SCMWEP_lim_0_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 1 alpha=pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim_1_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim_1_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim_1_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim_1_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 1, $\\alpha=\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_lim_1_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 1 alpha=pi/2
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim_2_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim_2_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim_2_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim_2_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 1, $\\alpha=\\pi/2$ Noisy')
plt.savefig('FID_SCMWEP_lim_2_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 1 alpha=3pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim_3_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim_3_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim_3_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim_3_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 1, $\\alpha=3\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_lim_3_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 1 alpha=pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim_4_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim_4_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim_4_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim_4_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 1, $\\alpha=\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim_4_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim 2 alpha=0
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_0_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_0_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_0_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_0_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=0$ Noisy')
plt.savefig('FID_SCMWEP_lim2_0_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_1_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_1_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_1_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_1_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_lim2_1_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi/2
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_2_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_2_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_2_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_2_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi/2$ Noisy')
plt.savefig('FID_SCMWEP_lim2_2_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=3pi/4
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_3_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_3_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_3_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_3_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=3\\pi/4$ Noisy')
plt.savefig('FID_SCMWEP_lim2_3_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_4_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_4_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_4_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_4_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim2_4_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 3 alpha=1.5pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_5_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_5_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_5_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_5_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=1.5\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim2_5_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=2pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_6_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_6_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_6_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_6_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=2\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim2_6_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=2.5pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_7_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_7_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_7_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_7_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=2.5\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim2_7_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=3pi
plt.figure()
plt.plot(rounds,[fid_SCMWEP_lim2_8_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[fid_SCMWEP_lim2_8_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[fid_SCMWEP_lim2_8_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[fid_SCMWEP_lim2_8_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Fidelity, $F=\\langle R\\psi | \\rho | R\\psi \\rangle$')
plt.ylim(0.45,1.05)
ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=3\\pi$ Noisy')
plt.savefig('FID_SCMWEP_lim2_8_noisy.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[diff_AT_clean[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_AT_clean[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_AT_clean[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_AT_clean[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='Reference')
plt.savefig('DIFF_Reference.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[diff_AT_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_AT_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_AT_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_AT_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='AT, Noisy')
plt.savefig('DIFF_AT_noisy.png', dpi=1000, bbox_inches='tight')

# %%
plt.figure()
plt.plot(rounds,[diff_SCM_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCM_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCM_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCM_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCM, Noisy')
plt.savefig('DIFF_SCM_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP full alpha=0
plt.figure()
plt.plot(rounds,[diff_SCMWEP_full_0_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_full_0_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_full_0_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_full_0_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=0$ Noisy')
plt.savefig('DIFF_SCMWEP_0_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi/4
plt.figure()
plt.plot(rounds,[diff_SCMWEP_full_1_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_full_1_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_full_1_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_full_1_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi/4$ Noisy')
plt.savefig('DIFF_SCMWEP_1_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi/2
plt.figure()
plt.plot(rounds,[diff_SCMWEP_full_2_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_full_2_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_full_2_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_full_2_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi/2$ Noisy')
plt.savefig('DIFF_SCMWEP_2_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=3pi/4
plt.figure()
plt.plot(rounds,[diff_SCMWEP_full_3_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_full_3_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_full_3_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_full_3_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=3\\pi/4$ Noisy')
plt.savefig('DIFF_SCMWEP_3_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP full alpha=pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_full_4_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_full_4_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_full_4_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_full_4_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP, $\\alpha=\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_4_noisy.png', dpi=1000, bbox_inches='tight')

# %%
## SCMWEP lim 2 alpha=0
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_0_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_0_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_0_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_0_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=0$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_0_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi/4
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_1_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_1_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_1_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_1_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi/4$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_1_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi/2
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_2_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_2_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_2_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_2_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi/2$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_2_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=3pi/4
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_3_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_3_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_3_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_3_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=3\\pi/4$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_3_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_4_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_4_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_4_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_4_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_4_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 3 alpha=1.5pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_5_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_5_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_5_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_5_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=1.5\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_5_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=2pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_6_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_6_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_6_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_6_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=2\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_6_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=2.5pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_7_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_7_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_7_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_7_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=2.5\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_7_noisy.png', dpi=1000, bbox_inches='tight')

## SCMWEP lim 2 alpha=3pi
plt.figure()
plt.plot(rounds,[diff_SCMWEP_lim2_8_noisy[i-1][0] for i in rounds],'k-s',linewidth=1,label='$p(\\theta)=1.0$ $(\\theta=0)$')
plt.plot(rounds,[diff_SCMWEP_lim2_8_noisy[i-1][3] for i in rounds],'b-s',linewidth=1,label='$p(\\theta)=0.8$ $(\\theta=\\pi/8)$')
plt.plot(rounds,[diff_SCMWEP_lim2_8_noisy[i-1][4] for i in rounds],'g-s',linewidth=1,label='$p(\\theta)=0.6$ $(\\theta=\\pi/6)$')
plt.plot(rounds,[diff_SCMWEP_lim2_8_noisy[i-1][6] for i in rounds],'r-s',linewidth=1,label='$p(\\theta)=0.5$ $(\\theta=\\pi/4)$')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('$\\Delta \\theta = |q(\\theta) - \\arctan(\\langle x\\rangle/\\langle z\\rangle)|$')
#plt.ylim(0.45,1.05)
#ylocations = (0.5,0.6,0.7,0.8,0.9,1.0)
#plt.yticks = (ypositions)
plt.legend(loc='best', title='SCMWEP lim 2, $\\alpha=3\\pi$ Noisy')
plt.savefig('DIFF_SCMWEP_lim2_8_noisy.png', dpi=1000, bbox_inches='tight')

# %%
def calc_fidelity(dt):
    return np.cos(dt)**2

disc = np.linspace(0,np.pi/2,100)
plt.figure()
plt.plot(disc,[calc_fidelity(i) for i in disc], 'k-')
plt.xlabel('$\\Delta\\theta = q(\\theta)-\\arctan(\\langle x \\rangle/\\langle z \\rangle)$')
plt.ylabel('Fidelity')
# Out:
# Text(0, 0.5, 'Fidelity')
